# %% [markdown]
# <a href="https://colab.research.google.com/github/hannaisadora88-stack/atividades-python/blob/main/atividade01_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Atividade 01 — Introdução ao Python

# %%
print("olá, mundo!")
print("curso técnico em informatica")
# Out:
# olá, mundo!
# curso técnico em informatica

# %%
disciplina=input("algoritimo e logica de programação: ")
conteudo=input(" linguagem Python: ")
atividade=input("atividade 01: ")
print("\n---informações da atividade---")
print("disciplina:",disciplina)
print("conteudo:",conteudo)
print("atividade:",atividade)
# Out:
# algoritimo e logica de programação:
#  linguagem Python: hhhj
# atividade 01: yryrf
#
# ---informações da atividade---
# disciplina:
# conteudo: hhhj
# atividade: yryrf

# %%
numero1=10
numero2=20
soma= numero1 + numero2
print("resultado:",soma)
# Out:
# resultado: 30
