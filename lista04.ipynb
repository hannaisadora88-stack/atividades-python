# %% [markdown]
# <a href="https://colab.research.google.com/github/hannaisadora88-stack/atividades-python/blob/main/lista04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# QUESTÃO 01

# %%
temperaturas = []
for i in range(7):
      temperaturas.append(float(input("temperatura: ")))
soma = 0
for t in temperaturas:
  soma += t
  media = soma/ len(temperaturas)
  acima = abaixo = iguais = 0
  for t in temperaturas:
    if t > media:
      acima += 1
    elif t < media:
      abaixo += 1
    else:
      iguais += 1
print("temperatura:", temperatura)
print("media:", media)
print("acima:", acima, "abaixo:",abaixo,"iguais:", iguais)

# %% [markdown]
# QUESTÃO 02

# %%
x = int(input("x: "))
y = int(input("y: "))
ponto = (x , y)

if ponto [0] == 0 and ponto [1] == 0:
  local = "origem"
elif ponto [0] == 0:
  local = "eixo y"
elif ponto [1] == 0 :
  local = "eixo x"
elif ponto [0] > 0 and ponto [1] > 0:
  local = "1 quadrante"
elif ponto [0] < 0 and ponto [1] > 0:
  local = "2 quadrante"
elif ponto [0] < 0 and ponto [1] < 0 :
  local = "3 quadrante"
else:
  local = "4 quadrante"
dist2=ponto[0] ** 2 + ponto[1] **2
print("ponto:", ponto)
print("local:", local)
print("distancia:",dist2)

# %% [markdown]
# QUATÃO 03

# %%
produto={}
produto["nome"] = input("produto")
produto["preço"] = float(input("preço: "))
produto["quantidade"] = int(input("quantidade: "))
produto["valor_estoque"] = produto["preço"] * produto["quantidade"]
print("produto:", produto)

# %% [markdown]
# QUESTÃO 04

# %%
numeros = []
for i in range (10):
  numeros.append(int(input("numeros: ")))
  atual = maior_seq=[1]
for i in range(1, len(numeros)):
  if numeros [1] > numeros [1]:
  atual += 1
  if atual > maior_seq:

else:
  print("numero:", numeros)

#pensarnaresoluçãodessaquestão
